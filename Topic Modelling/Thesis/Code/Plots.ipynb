# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
top2vec_plot_path = "/content/drive/MyDrive/Tesi/Plots/Top2Vec/top2vec_"
bar_charts_path = "/content/drive/MyDrive/Tesi/Plots/Comparisons/BarCharts/bar_chart_"
line_charts_path = "/content/drive/MyDrive/Tesi/Plots/Comparisons/LineCharts/linechart_"
radar_chart_path = "/content/drive/MyDrive/Tesi/Plots/Comparisons/RadarChart/"

# %% [markdown]
# # Importing libraries

# %%
# %%capture
# ! pip install matplotlib --upgrade
# import matplotlib
# matplotlib.__version__

# %%
# %%capture
! pip install -U kaleido

# %%
# %%capture
# !sudo apt install cm-super dvipng texlive-latex-extra texlive-latex-recommended

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
from matplotlib.patches import Patch
import plotly.graph_objects as go

import numpy as np
from math import log
import csv

import os
from os import listdir
from os.path import isfile, join

import seaborn as sns
import pandas as pd

# %%
plt.rcParams['text.usetex'] = True

# %% [markdown]
# # Plot results

# %% [markdown]
# ## Different embeddings for Top2Vec results

# %% [markdown]
# ### Initializing dictionaries of results

# %%
# Tourpedia
# Test 1: {'num_topics': 14.0, 'diversity': 0.6646508527162551, 'irbo': 0.9248580358082984, 'c_npmi': -0.3392723909802706, 'c_uci': -10.056536471064778, 'c_umass': -12.516059682918238, 'c_v': 0.379202571898987}
# Test 2: {'num_topics': 10.4, 'diversity': 0.7504423419717537, 'irbo': 0.9288156296675032, 'c_npmi': -0.3417446746074659, 'c_uci': -10.11468118542824, 'c_umass': -12.148202390495069, 'c_v': 0.36091933308035257}
# Test 3: {'num_topics': 12.5, 'diversity': 0.71320497265892, 'irbo': 0.9304003475795326, 'c_npmi': -0.3399417248539535, 'c_uci': -10.079341668060895, 'c_umass': -12.081265859669452, 'c_v': 0.3555298552962292}
# Test 4: {'num_topics': 12.3, 'diversity': 0.6846377960275019, 'irbo': 0.9106581607350994, 'c_npmi': -0.34269620545276597, 'c_uci': -10.16429263023584, 'c_umass': -12.16444391412844, 'c_v': 0.36720958202546217}
# Test 5: {'num_topics': 50.6, 'diversity': 0.43127279744684294, 'irbo': 0.9076632542079567, 'c_npmi': -0.26074473164358536, 'c_uci': -8.02860455569444, 'c_umass': -9.385186098046553, 'c_v': 0.3579163859461168}
# Test 6: {'num_topics': 46.5, 'diversity': 0.5575727956399951, 'irbo': 0.9638680338482104, 'c_npmi': -0.2228302327630239, 'c_uci': -6.835665010150363, 'c_umass': -8.038410827137188, 'c_v': 0.35506224804263414}

# %%
# Tourpedia deep-learn
#{'num_topics': 123.4, 'diversity': 0.28649124548294214, 'irbo': 0.9701924439751174, 'c_npmi': -0.2712415644313974, 'c_uci': -8.475234117271949, 'c_umass': -9.693998767110182, 'c_v': 0.3605059974423493}

# %%
# Easytour deep-learn
#{'num_topics': 123.8, 'diversity': 0.28380105658599053, 'irbo': 0.9697045264941497, 'c_npmi': -0.2683759385708016, 'c_uci': -8.42199554359335, 'c_umass': -9.803253199524882, 'c_v': 0.3629542872232882}

# %%
#Easytour speed=learn
doc_vec_chunk = {'num_topics': 41.5, 'diversity': 0.865787350177861, 'irbo': 0.9959754211984789, 'c_npmi': -0.1373683685997297, 'c_uci': -5.278008290149552, 'c_umass': -7.346481654847873, 'c_v': 0.5107702127978502}
doc_vec_no_chunk = {'num_topics': 50.7, 'diversity': 0.8315862370323801, 'irbo': 0.9949932208814929, 'c_npmi': -0.09789133017186936, 'c_uci': -4.493559342240369, 'c_umass': -5.202886553951696, 'c_v': 0.570103538736817}
test3 = {'num_topics': 41.9, 'diversity': 0.857653229530839, 'irbo': 0.9952818727994963, 'c_npmi': -0.12757823751725722, 'c_uci': -5.13572903976611, 'c_umass': -6.378286760702936, 'c_v': 0.5243180559056222}
test4 = {'num_topics': 48.9, 'diversity': 0.8391012828303197, 'irbo': 0.9949673000496653, 'c_npmi': -0.10066076245349853, 'c_uci': -4.542946713800365, 'c_umass': -5.458728659514632, 'c_v': 0.5621089896458603}
sentence_encoder = {'num_topics': 2.0, 'diversity': 1.0, 'irbo': 1.0, 'c_npmi': -0.2541045060224748, 'c_uci': -7.217034673229368, 'c_umass': -10.098948792556012, 'c_v': 0.4286507949183339}
distiluse = {'num_topics': 29.8, 'diversity': 0.7368369980667648, 'irbo': 0.9793781272692582, 'c_npmi': -0.2675844795100995, 'c_uci': -8.059502033645327, 'c_umass': -7.989346599207755, 'c_v': 0.35477216072877116}

# %%
# Easytour doc2vec deep-learn with no chunking
# Results-> td: 0.9 IRBO: 0.9969803964614286 npmi: -0.17218274910710218 uci: -6.143046945079111 umass: -6.782536948865163 c_v: 0.478452525318317
# Results-> td: 0.9266666666666666 IRBO: 0.9980138967565585 npmi: -0.1262307584416638 uci: -5.166784660056625 umass: -6.033476898147242 c_v: 0.5281934764433523
# Results-> td: 0.8962962962962963 IRBO: 0.997261164575292 npmi: -0.13476882494022077 uci: -5.364664275221608 umass: -6.03478825342013 c_v: 0.52714363410314
# Results-> td: 0.8877551020408163 IRBO: 0.996890229005266 npmi: -0.1252239580496042 uci: -5.163742620715894 umass: -5.483270786795056 c_v: 0.5413164052220533
# Results-> td: 0.9153846153846154 IRBO: 0.997063010873742 npmi: -0.15795704686052067 uci: -5.812196651383993 umass: -6.836945344210743 c_v: 0.4816398346041236
test_dl_no_chunk = {'num_topics': 45.4, 'diversity': 0.905220536077679, 'irbo': 0.9972417395344573, 'c_npmi': -0.1432726674798223, 'c_uci': -5.530087030491446, 'c_umass': -6.234203646287667, 'c_v': 0.5113491751381972}

# %%
# Easytour doc2vec deep-learn with chunking
# Results-> td: 0.8914893617021277 IRBO: 0.9971656709206819 npmi: -0.1308487926208886 uci: -5.30194766131722 umass: -5.476412877646203 c_v: 0.5422392622097317
# Results-> td: 0.8956521739130435 IRBO: 0.9971722130667081 npmi: -0.13382085219687098 uci: -5.304492885602258 umass: -5.681009558797488 c_v: 0.5371819134275122
# Results-> td: 0.9116279069767442 IRBO: 0.9975708717033934 npmi: -0.11670049879932072 uci: -4.966533465069488 umass: -5.760114393502795 c_v: 0.5478441614545319
# Results-> td: 0.9116279069767442 IRBO: 0.9973832734166588 npmi: -0.12473164857937653 uci: -5.131525276959297 umass: -5.788160305228256 c_v: 0.5451890537422714
# Results-> td: 0.8916666666666667 IRBO: 0.9970114593511589 npmi: -0.1297155512050485 uci: -5.2463290112138345 umass: -5.890849690840945 c_v: 0.5357541992927977

# %%
t1 = {"diversity": 0.8914893617021277, "irbo": 0.9971656709206819, "c_npmi": -0.1308487926208886, "c_uci": -5.30194766131722, "c_umass": -5.476412877646203, "c_v": 0.5422392622097317}
t2 =  {"diversity": 0.8956521739130435, "irbo": 0.9971722130667081, "c_npmi": -0.13382085219687098, "c_uci": -5.304492885602258, "c_umass": -5.681009558797488, "c_v": 0.5371819134275122}
t3 = {"diversity": 0.9116279069767442, "irbo": 0.9975708717033934, "c_npmi": -0.11670049879932072, "c_uci": -4.966533465069488, "c_umass": -5.760114393502795, "c_v": 0.5478441614545319}
t4 =  {"diversity": 0.9116279069767442, "irbo": 0.9973832734166588, "c_npmi": -0.12473164857937653, "c_uci": -5.131525276959297, "c_umass": -5.788160305228256, "c_v": 0.5451890537422714}
t5 = {"diversity": 0.8916666666666667, "irbo": 0.9970114593511589, "c_npmi": -0.1297155512050485, "c_uci": -5.2463290112138345, "c_umass": -5.890849690840945, "c_v": 0.5357541992927977}
metrics = ["diversity", "irbo", "c_npmi", "c_uci", "c_umass", "c_v"]
t = [t1,t2,t3,t4,t5]
test_dl_chunk = dict()
for m in metrics:
  test_dl_chunk[m] = 0

for m in metrics:
  for i in range(len(t)):
    test_dl_chunk[m] += t[i][m]

for j in test_dl_chunk.keys():
  test_dl_chunk[j] = test_dl_chunk[j]/len(t)

print(test_dl_chunk)
# Out:
# {'diversity': 0.9004128032470653, 'irbo': 0.9972606976917202, 'c_npmi': -0.12716346868030107, 'c_uci': -5.190165660032419, 'c_umass': -5.719309365203137, 'c_v': 0.541641718025369}

# %% [markdown]
# ### Plots

# %%
metrics = ["diversity", "irbo", "c_npmi", "c_uci", "c_umass", "c_v"]
math_metrics = [r"$topic diversity$", r"$irbo$", r"$c_{npmi}$", r"$c_{uci}$", r"$c_{umass}$", r"$c_{v}$"]
tests_done = [doc_vec_chunk, doc_vec_no_chunk, test_dl_chunk, test_dl_no_chunk, sentence_encoder, distiluse]
test_str = ["Doc2Vec with chunking", "Doc2Vec without chunking", "deeplearn with chunking", "deeplearn without chunking", "sentence encoder", "distiluse"]

# %%
cols = ["model", "c_uci", "c_v",	"c_npmi",	"c_umass",	"diversity",	"irbo"]
tests_list = []
for i,j in zip(tests_done, test_str):
  t = [j]
  for v in cols:
    if v == "model":
      continue
    t.append(i[v])
  tests_list.append(t)

tests_df = pd.DataFrame(tests_list, columns = cols)
tests_df
# Out:
#                         model     c_uci       c_v    c_npmi    c_umass  \
# 0       Doc2Vec with chunking -5.278008  0.510770 -0.137368  -7.346482
# 1    Doc2Vec without chunking -4.493559  0.570104 -0.097891  -5.202887
# 2     deeplearn with chunking -5.190166  0.541642 -0.127163  -5.719309
# 3  deeplearn without chunking -5.530087  0.511349 -0.143273  -6.234204
# 4            sentence encoder -7.217035  0.428651 -0.254105 -10.098949
# 5                   distiluse -8.059502  0.354772 -0.267584  -7.989347
#
#    diversity      irbo
# 0   0.865787  0.995975
# 1   0.831586  0.994993
# 2   0.900413  0.997261
# 3   0.905221  0.997242
# 4   1.000000  1.000000
# 5   0.736837  0.979378

# %%
colors = ["black", "dimgray", "darkgrey", "gainsboro", "white", "silver"]

sns.set(style='white', rc={'figure.figsize':(12,8)}, font_scale=1.6)
m = "c_uci"
for i,m in enumerate(metrics):
  plt.figure()
  plt.margins(x=0.1)
  
  s = sns.barplot(y="model", x=m, data=tests_df, orient="h", palette = colors, edgecolor=".5")
  plt.ylabel("Models")#, fontdict={"fontsize":15})

  if m == "irbo":
    plt.xlabel("Topic diversity ({})".format(math_metrics[i]))#, fontdict={"fontsize":15})
  elif m == "diversity":
    plt.xlabel("\\textit{topic diversity}")#, fontdict={"fontsize":15})
  else:
    plt.xlabel("Coherence value ({})".format(math_metrics[i]))#, fontdict={"fontsize":15})
    
  # add bar values
  # for bars_group in s.containers:
  #   s.bar_label(bars_group, padding=3, fontsize=10)

  #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))#, fontsize=15)
  sns.despine()
  plt.tight_layout()
  plt.savefig(top2vec_plot_path+m+'_seaborn.png')

# %%
for i,m in enumerate(metrics):
  ypoints = []
  for k in tests_done:
    ypoints.append(k[m])
  fig, ax = plt.subplots(figsize=(30, 15))
  if m == "diversity" or m == "irbo":
    ax.bar(test_str, ypoints, label=ypoints, log=True, width=0.4)
  else:
    ax.bar(test_str, ypoints, label=ypoints, width=0.4)

  plt.yticks(fontsize=15)
  plt.xticks(fontsize=15)
  ax.set_title("Plot {} score".format(math_metrics[i]), fontsize=15)
  ax.set_label("Versions tested of Top2Vec")
  #ax.set_ylabel("Metric score: {}".format(m))

  plt.show()
  fig.savefig(top2vec_plot_path+m+'.png')

# %%
fig, axs = plt.subplots(2, 3, figsize=(50,25))
pos = [[0,0],[0,1],[0,2],[1,0],[1,1],[1,2]]
hatches = ["//", "xx", "--", ".", "*", "+"]
legend_elements = []
for i in hatches:
  legend_elements.append(Patch(facecolor='b', edgecolor='black', alpha=0.9, hatch=i))

for i,m in enumerate(metrics):
  ypoints = []
  for k in tests_done:
    ypoints.append(k[m])
  p = pos[i]
  axs[p[0], p[1]].plot(figsize=(8, 4))
  if m == "diversity" or m == "irbo":
    bars = axs[p[0], p[1]].bar(test_str, ypoints, label=ypoints, log=True,  width=0.4)
  else:
    bars = axs[p[0], p[1]].bar(test_str, ypoints, label=ypoints,  width=0.4)
  
  for i in range(len(bars)):
    bars[i].set(hatch = hatches[i], color="w", edgecolor= "black")

  plt.sca(axs[p[0], p[1]])
  plt.xticks(fontsize=15)
  plt.yticks(fontsize=15)
  axs[p[0], p[1]].set_ylabel("Plot {} score (higher value is better)".format(math_metrics[i]), fontsize=18)
  #axs[p[0], p[1]].set_xlabel("Versions tested of Top2Vec", fontsize=18)
  #axs[p[0], p[1]].set_ylabel("Metric score".format(m))
  #print(hatches, type(hatches), test_str, type(test_str))
  #axs[p[0], p[1]].legend(handles=legend_elements, labels=test_str)

fig.savefig(top2vec_plot_path+'all_metrics.png')

# %%
labels = ["doc_vec_chunk", "doc_vec_no_chunk", "test_dl_chunk", "test_dl_no_chunk", "sentence_encoder", "distiluse"]
doc_vec_chunk_v = [doc_vec_chunk[m] for m in metrics]
doc_vec_no_chunk_v = [doc_vec_no_chunk[m] for m in metrics]
test_dl_chunk_v = [test_dl_chunk[m] for m in metrics] 
test_dl_no_chunk_v = [test_dl_no_chunk[m] for m in metrics]
sentence_encoder_v = [sentence_encoder[m] for m in metrics] 
distiluse_v = [distiluse[m] for m in metrics]
tests = [doc_vec_chunk_v, doc_vec_no_chunk_v, test_dl_chunk_v, test_dl_no_chunk_v, sentence_encoder_v, distiluse_v]

x = np.arange(len(labels))  # the label locations
width = 0.10  # the width of the bars
colors = ["gold", "dodgerblue", "red", "lime", "darkorange", "cyan"]
fig, ax = plt.subplots(figsize=(10, 10))

rects = []
for i,e in enumerate(tests):
  rects.append(ax.bar(x - (width*(2.5-i)), e, width, label=labels[i], color=colors[i])) #, log=True

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by metric and model')
ax.set_xticks(x, labels)
ax.legend()

for r in rects:
  ax.set_xticklabels(metrics)

fig.tight_layout()

plt.show()

# %%
# for t,t_s in zip(tests_done, test_str):
#   print(t_s, t["num_topics"])

# %% [markdown]
# ## Comparisons of the methods

# %% [markdown]
# ### Importing and pre-processing data

# %%
results_path = "/content/drive/MyDrive/Tesi/results_csv/"

# %%
keys = ["dataset", "c_uci", "c_v", "c_umass", "c_npmi",	"topic_diversity", "#topics",	"irbo"]
metrics = ["topic_diversity", "irbo", "c_npmi", "c_uci", "c_umass", "c_v"]
math_metrics = [r"$topic diversity$", r"$irbo$", r"$c_{npmi}$", r"$c_{uci}$", r"$c_{umass}$", r"$c_{v}$"]
models = ["LDA", "Top2Vec", "NMF", "BERTopic", "RoBERTa", "CTM", "ETM"]
datasets = ["ATE", "TAT", "ET", "TP", "20NG"]
data_dict = {"AirBnB":"ATE", "TripAdvisor":"TAT", "EasyTour":"ET", "20NewsGroup":"20NG", "TourPedia":"TP"}
colors_bw = ["black", "dimgray", "darkgrey", "gainsboro", "white", "silver", "whitesmoke"]
colors = ["limegreen", "orange", "royalblue", "orangered", "cyan", "magenta", "yellow"]

# %%
results = dict()
csv_files = [(f,join(results_path, f)) for f in listdir(results_path) if isfile(join(results_path, f))]
datasets_from_csv = set()
for f in csv_files:
  reader = csv.reader(open(f[1], 'r'))
  next(reader, None)
  for m in models:
    if m in f[1]:
      results[m] = dict()
      break
  #results[f[0]] = dict()
  for row in reader:
    for k,v in zip(keys, row):
      if k != "dataset":
        results[m][dataset_csv][k] = float(v)
      else:
        results[m][data_dict[v]] = dict()
        dataset_csv = data_dict[v]
        datasets_from_csv.add(v)
  print("File: {} ... done".format(f[1]))

datasets_from_csv = list(datasets_from_csv)
# Out:
# File: /content/drive/MyDrive/Tesi/results_csv/Result_Sheet - LDA.csv ... done
# File: /content/drive/MyDrive/Tesi/results_csv/Result_Sheet - NMF.csv ... done
# File: /content/drive/MyDrive/Tesi/results_csv/Result_Sheet - ETM.csv ... done
# File: /content/drive/MyDrive/Tesi/results_csv/Result_Sheet - BERTopic Raw Data.csv ... done
# File: /content/drive/MyDrive/Tesi/results_csv/Result_Sheet - RoBERTa Raw Data.csv ... done
# File: /content/drive/MyDrive/Tesi/results_csv/Result_Sheet - CTM.csv ... done
# File: /content/drive/MyDrive/Tesi/results_csv/Result_Sheet - Top2Vec Raw Data11.csv ... done

# %%
#datasets_from_csv

# %%
results
# Out:
# {'LDA': {'ATE': {'c_uci': -6.56,
#    'c_v': 0.45,
#    'c_umass': -8.45,
#    'c_npmi': -0.19,
#    'topic_diversity': 0.87,
#    '#topics': 14.0,
#    'irbo': 0.98},
#   'TAT': {'c_uci': -6.68,
#    'c_v': 0.42,
#    'c_umass': -8.68,
#    'c_npmi': -0.19,
#    'topic_diversity': 0.94,
#    '#topics': 16.0,
#    'irbo': 0.99},
#   'ET': {'c_uci': -0.11,
#    'c_v': 0.37,
#    'c_umass': -1.65,
#    'c_npmi': -0.01,
#    'topic_diversity': 0.21,
#    '#topics': 22.0,
#    'irbo': 0.56},
#   '20NG': {'c_uci': -6.23,
#    'c_v': 0.34,
#    'c_umass': -5.92,
#    'c_npmi': -0.21,
#    'topic_diversity': 0.6,
#    '#topics': 111.0,
#    'irbo': 0.87},
#   'TP': {'c_uci': -1.06,
#    'c_v': 0.45,
#    'c_umass': -3.62,
#    'c_npmi': -0.03,
#    'topic_diversity': 0.38,
#    '#topics': 14.0,
#    'irbo': 0.7}},
#  'NMF': {'ATE': {'c_uci': 0.01,
#    'c_v': 0.7,
#    'c_umass': -2.09,
#    'c_npmi': 0.12,
#    'topic_diversity': 0.83,
#    '#topics': 14.0,
#    'irbo': 0.98},
#   'TAT': {'c_uci': 0.59,
#    'c_v': 0.79,
#    'c_umass': -1.7,
#    'c_npmi': 0.21,
#    'topic_diversity': 0.82,
#    '#topics': 16.0,
#    'irbo': 0.98},
#   'ET': {'c_uci': -0.05,
#    'c_v': 0.59,
#    'c_umass': -3.03,
#    'c_npmi': 0.09,
#    'topic_diversity': 0.82,
#    '#topics': 22.0,
#    'irbo': 0.986},
#   '20NG': {'c_uci': -1.05,
#    'c_v': 0.49,
#    'c_umass': -3.46,
#    'c_npmi': 0.03,
#    'topic_diversity': 0.58,
#    '#topics': 111.0,
#    'irbo': 0.99},
#   'TP': {'c_uci': -3.1,
#    'c_v': 0.44,
#    'c_umass': -6.27,
#    'c_npmi': -0.07,
#    'topic_diversity': 0.65,
#    '#topics': 14.0,
#    'irbo': 0.947}},
#  'ETM': {'ATE': {'c_uci': -0.4,
#    'c_v': 0.55,
#    'c_umass': -1.85,
#    'c_npmi': -0.03,
#    'topic_diversity': 0.65,
#    '#topics': 14.0,
#    'irbo': 0.91},
#   'TAT': {'c_uci': -0.03,
#    'c_v': 0.45,
#    'c_umass': -1.72,
#    'c_npmi': 0.03,
#    'topic_diversity': 0.26,
#    '#topics': 16.0,
#    'irbo': 0.56},
#   'ET': {'c_uci': 0.06,
#    'c_v': 0.39,
#    'c_umass': -0.79,
#    'c_npmi': 0.01,
#    'topic_diversity': 0.31,
#    '#topics': 22.0,
#    'irbo': 0.7},
#   '20NG': {'c_uci': 0.19,
#    'c_v': 0.51,
#    'c_umass': -1.91,
#    'c_npmi': 0.03,
#    'topic_diversity': 0.09,
#    '#topics': 111.0,
#    'irbo': 0.82},
#   'TP': {'c_uci': -0.03,
#    'c_v': 0.49,
#    'c_umass': -1.49,
#    'c_npmi': -0.001,
#    'topic_diversity': 0.34,
#    '#topics': 14.0,
#    'irbo': 0.66}},
#  'BERTopic': {'ATE': {'c_uci': -0.1,
#    'c_v': 0.34,
#    'c_umass': -0.63,
#    'c_npmi': -0.01,
#    'topic_diversity': 0.47,
#    '#topics': 3.0,
#    'irbo': 0.21},
#   'TAT': {'c_uci': -2.66,
#    'c_v': 0.53,
#    'c_umass': -2.02,
#    'c_npmi': -0.04,
#    'topic_diversity': 0.61,
#    '#topics': 45.0,
#    'irbo': 0.96},
#   'ET': {'c_uci': -1.53,
#    'c_v': 0.31,
#    'c_umass': -4.72,
#    'c_npmi': -0.029,
#    'topic_diversity': 0.45,
#    '#topics': 74.9,
#    'irbo': 0.925},
#   '20NG': {'c_uci': -2.8,
#    'c_v': 0.51,
#    'c_umass': -5.06,
#    'c_npmi': -0.03,
#    'topic_diversity': 0.78,
#    '#topics': 216.0,
#    'irbo': 0.99},
#   'TP': {'c_uci': -6.59,
#    'c_v': 0.34,
#    'c_umass': -12.35,
#    'c_npmi': -0.17,
#    'topic_diversity': 0.71,
#    '#topics': 142.4,
#    'irbo': 0.996}},
#  'RoBERTa': {'ATE': {'c_uci': -0.14,
#    'c_v': 0.34,
#    'c_umass': -0.83,
#    'c_npmi': -0.01,
#    'topic_diversity': 0.25,
#    '#topics': 10.0,
#    'irbo': 0.31},
#   'TAT': {'c_uci': -2.69,
#    'c_v': 0.54,
#    'c_umass': -1.86,
#    'c_npmi': -0.05,
#    'topic_diversity': 0.57,
#    '#topics': 44.0,
#    'irbo': 0.94},
#   'ET': {'c_uci': -1.32,
#    'c_v': 0.31,
#    'c_umass': -4.72,
#    'c_npmi': -0.061,
#    'topic_diversity': 0.59,
#    '#topics': 14.1,
#    'irbo': 0.69},
#   '20NG': {'c_uci': -1.64,
#    'c_v': 0.52,
#    'c_umass': -3.43,
#    'c_npmi': -0.01,
#    'topic_diversity': 0.75,
#    '#topics': 90.0,
#    'irbo': 0.97},
#   'TP': {'c_uci': -5.91,
#    'c_v': 0.36,
#    'c_umass': -11.91,
#    'c_npmi': -0.15,
#    'topic_diversity': 0.67,
#    '#topics': 105.5,
#    'irbo': 0.991}},
#  'CTM': {'ATE': {'c_uci': -8.93,
#    'c_v': 0.37,
#    'c_umass': -5.51,
#    'c_npmi': -0.3,
#    'topic_diversity': 0.88,
#    '#topics': 14.0,
#    'irbo': 0.99},
#   'TAT': {'c_uci': -4.61,
#    'c_v': 0.61,
#    'c_umass': -4.44,
#    'c_npmi': -0.08,
#    'topic_diversity': 0.78,
#    '#topics': 16.0,
#    'irbo': 0.97},
#   'ET': {'c_uci': -2.34,
#    'c_v': 0.58,
#    'c_umass': -4.94,
#    'c_npmi': -0.03,
#    'topic_diversity': 0.61,
#    '#topics': 22.0,
#    'irbo': 0.96},
#   '20NG': {'c_uci': -3.53,
#    'c_v': 0.42,
#    'c_umass': -2.67,
#    'c_npmi': -0.11,
#    'topic_diversity': 0.48,
#    '#topics': 111.0,
#    'irbo': 0.97},
#   'TP': {'c_uci': -6.57,
#    'c_v': 0.51,
#    'c_umass': -10.7,
#    'c_npmi': -0.21,
#    'topic_diversity': 0.61,
#    '#topics': 14.0,
#    'irbo': 0.92}},
#  'Top2Vec': {'ATE': {'c_uci': -3.42,
#    'c_v': 0.62,
#    'c_umass': -1.52,
#    'c_npmi': -0.06,
#    'topic_diversity': 0.92,
#    '#topics': 6.0,
#    'irbo': 0.98},
#   'TAT': {'c_uci': -3.42,
#    'c_v': 0.7,
#    'c_umass': -1.17,
#    'c_npmi': -0.01,
#    'topic_diversity': 0.94,
#    '#topics': 6.0,
#    'irbo': 0.98},
#   'ET': {'c_uci': -4.57,
#    'c_v': 0.56,
#    'c_umass': -5.38,
#    'c_npmi': -0.1,
#    'topic_diversity': 0.84,
#    '#topics': 50.1,
#    'irbo': 0.995},
#   '20NG': {'c_uci': -2.72,
#    'c_v': 0.64,
#    'c_umass': -2.74,
#    'c_npmi': -0.02,
#    'topic_diversity': 0.91,
#    '#topics': 83.0,
#    'irbo': 0.998},
#   'TP': {'c_uci': -6.72,
#    'c_v': 0.35,
#    'c_umass': -8.1,
#    'c_npmi': -0.22,
#    'topic_diversity': 0.61,
#    '#topics': 40.8,
#    'irbo': 0.97}}}

# %%
# Create dataframe for seaborn
r = []
csv_files = [(f,join(results_path, f)) for f in listdir(results_path) if isfile(join(results_path, f))]

for f in csv_files:
  reader = csv.reader(open(f[1], 'r'))
  next(reader, None)
  for m in models:
    if m in f[1]:
      model_used = m
      break
  for row in reader:
    row[-1] = model_used
    if data_dict[row[0]]:
      row[0] = data_dict[row[0]]
    try:
      row.remove('')
      r.append(row)
    except:
      r.append(row)
      continue
  print("File: {} ... done".format(f[1]))

results_df = pd.DataFrame(r, columns = ["dataset", "c_uci", "c_v", "c_umass", "c_npmi",	"topic_diversity", "#topics",	"irbo", "model"])
results_df[metrics] = results_df[metrics].apply(pd.to_numeric)
# Out:
# File: /content/drive/MyDrive/Tesi/results_csv/Result_Sheet - LDA.csv ... done
# File: /content/drive/MyDrive/Tesi/results_csv/Result_Sheet - NMF.csv ... done
# File: /content/drive/MyDrive/Tesi/results_csv/Result_Sheet - ETM.csv ... done
# File: /content/drive/MyDrive/Tesi/results_csv/Result_Sheet - BERTopic Raw Data.csv ... done
# File: /content/drive/MyDrive/Tesi/results_csv/Result_Sheet - RoBERTa Raw Data.csv ... done
# File: /content/drive/MyDrive/Tesi/results_csv/Result_Sheet - CTM.csv ... done
# File: /content/drive/MyDrive/Tesi/results_csv/Result_Sheet - Top2Vec Raw Data11.csv ... done

# %%
def model_sorter(column):
    correspondence = {model: order for order, model in enumerate(models)}
    return column.map(correspondence)

results_df = results_df.sort_values(by='model', key=model_sorter)

# %%
results_df
# Out:
#    dataset  c_uci   c_v  c_umass  c_npmi  topic_diversity #topics   irbo  \
# 0      ATE  -6.56  0.45    -8.45  -0.190             0.87      14  0.980
# 1      TAT  -6.68  0.42    -8.68  -0.190             0.94      16  0.990
# 2       ET  -0.11  0.37    -1.65  -0.010             0.21      22  0.560
# 3     20NG  -6.23  0.34    -5.92  -0.210             0.60     111  0.870
# 4       TP  -1.06  0.45    -3.62  -0.030             0.38      14  0.700
# 32      ET  -4.57  0.56    -5.38  -0.100             0.84    50.1  0.995
# 31     TAT  -3.42  0.70    -1.17  -0.010             0.94       6  0.980
# 30     ATE  -3.42  0.62    -1.52  -0.060             0.92       6  0.980
# 33    20NG  -2.72  0.64    -2.74  -0.020             0.91      83  0.998
# 34      TP  -6.72  0.35    -8.10  -0.220             0.61    40.8  0.970
# 5      ATE   0.01  0.70    -2.09   0.120             0.83      14  0.980
# 6      TAT   0.59  0.79    -1.70   0.210             0.82      16  0.980
# 7       ET  -0.05  0.59    -3.03   0.090             0.82      22  0.986
# 8     20NG  -1.05  0.49    -3.46   0.030             0.58     111  0.990
# 9       TP  -3.10  0.44    -6.27  -0.070             0.65      14  0.947
# 17      ET  -1.53  0.31    -4.72  -0.029             0.45    74.9  0.925
# 15     ATE  -0.10  0.34    -0.63  -0.010             0.47       3  0.210
# 16     TAT  -2.66  0.53    -2.02  -0.040             0.61      45  0.960
# 18    20NG  -2.80  0.51    -5.06  -0.030             0.78     216  0.990
# 19      TP  -6.59  0.34   -12.35  -0.170             0.71   142.4  0.996
# 24      TP  -5.91  0.36   -11.91  -0.150             0.67   105.5  0.991
# 23    20NG  -1.64  0.52    -3.43  -0.010             0.75      90  0.970
# 22      ET  -1.32  0.31    -4.72  -0.061             0.59    14.1  0.690
# 20     ATE  -0.14  0.34    -0.83  -0.010             0.25      10  0.310
# 21     TAT  -2.69  0.54    -1.86  -0.050             0.57      44  0.940
# 25     ATE  -8.93  0.37    -5.51  -0.300             0.88      14  0.990
# 26     TAT  -4.61  0.61    -4.44  -0.080             0.78      16  0.970
# 27      ET  -2.34  0.58    -4.94  -0.030             0.61      22  0.960
# 28    20NG  -3.53  0.42    -2.67  -0.110             0.48     111  0.970
# 29      TP  -6.57  0.51   -10.70  -0.210             0.61      14  0.920
# 14      TP  -0.03  0.49    -1.49  -0.001             0.34      14  0.660
# 13    20NG   0.19  0.51    -1.91   0.030             0.09     111  0.820
# 12      ET   0.06  0.39    -0.79   0.010             0.31      22  0.700
# 11     TAT  -0.03  0.45    -1.72   0.030             0.26      16  0.560
# 10     ATE  -0.40  0.55    -1.85  -0.030             0.65      14  0.910
#
#        model
# 0        LDA
# 1        LDA
# 2        LDA
# 3        LDA
# 4        LDA
# 32   Top2Vec
# 31   Top2Vec
# 30   Top2Vec
# 33   Top2Vec
# 34   Top2Vec
# 5        NMF
# 6        NMF
# 7        NMF
# 8        NMF
# 9        NMF
# 17  BERTopic
# 15  BERTopic
# 16  BERTopic
# 18  BERTopic
# 19  BERTopic
# 24   RoBERTa
# 23   RoBERTa
# 22   RoBERTa
# 20   RoBERTa
# 21   RoBERTa
# 25       CTM
# 26       CTM
# 27       CTM
# 28       CTM
# 29       CTM
# 14       ETM
# 13       ETM
# 12       ETM
# 11       ETM
# 10       ETM

# %% [markdown]
# ### Radar Charts

# %%
dash_styles = ("solid", "dot", "dash", "longdash", "dashdot", "longdashdot")
markers = (0,107,13,122,130,135)

# %%
# Set use_colors to False to have plots in shades of gray
def radar_chart_metrics(used_colors, remove_diversity=False, save_plots=False, use_dash=False):

  min_df = results_df.min()
  max_df = results_df.max()
  if remove_diversity:
    metrics_radar_chart = list(filter(lambda x: x != "irbo" and x != "topic_diversity", metrics))
  else:
    metrics_radar_chart = metrics

  for i in metrics_radar_chart:
    min_value = min_df[i]
    max_value = max_df[i]

    fig = go.Figure()

    for m,c,style in zip(models,used_colors,dash_styles):
      v = []
      for d in datasets:
        v.append(results[m][d][i])

      if use_dash:
        line_style = {"color":c, "dash":style}
      else:
        line_style = {"color":c}
      fig.add_trace(go.Scatterpolar(
            r=v,
            theta=datasets,
            fill='none', #toself to color area
            name=m,
            line = line_style
      ))

    fig.update_layout(
      #title = "Comparison for {} metric".format(i),
      polar=dict(
        radialaxis=dict(
          visible=True,
          range=[min_value, max_value]
        )),
      showlegend=True
    )

    fig.show()
    if save_plots:
      if use_dash:
        plot_path = radar_chart_path + "Metrics/radar_chart_dashedLines_"+ i + ".png"
      else:
        plot_path = radar_chart_path + "Metrics/radar_chart_colored_"+ i + ".png"

      fig.write_image(plot_path)

radar_chart_metrics(used_colors=colors, save_plots=True, use_dash=False)
radar_chart_metrics(used_colors=colors_bw, save_plots=True, use_dash=False)
radar_chart_metrics(used_colors=colors_bw, save_plots=False, use_dash=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cc3322c6-c5fa-4e91-8997-4d3f4b9fa29e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc3322c6-c5fa-4e91-8997-4d3f4b9fa29e")) {                    Plotly.newPlot(                        "cc3322c6-c5fa-4e91-8997-4d3f4b9fa29e",                        [{"fill":"none","line":{"color":"limegreen"},"name":"LDA","r":[0.87,0.94,0.21,0.38,0.6],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orange"},"name":"Top2Vec","r":[0.92,0.94,0.84,0.61,0.91],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"royalblue"},"name":"NMF","r":[0.83,0.82,0.82,0.65,0.58],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orangered"},"name":"BERTopic","r":[0.47,0.61,0.45,0.71,0.78],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"cyan"},"name":"RoBERTa","r":[0.25,0.57,0.59,0.67,0.75],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"magenta"},"name":"CTM","r":[0.88,0.78,0.61,0.61,0.48],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d8e7da58-2508-47e2-9984-b1ba676a1c90" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8e7da58-2508-47e2-9984-b1ba676a1c90")) {                    Plotly.newPlot(                        "d8e7da58-2508-47e2-9984-b1ba676a1c90",                        [{"fill":"none","line":{"color":"limegreen"},"name":"LDA","r":[0.98,0.99,0.56,0.7,0.87],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orange"},"name":"Top2Vec","r":[0.98,0.98,0.995,0.97,0.998],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"royalblue"},"name":"NMF","r":[0.98,0.98,0.986,0.947,0.99],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orangered"},"name":"BERTopic","r":[0.21,0.96,0.925,0.996,0.99],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"cyan"},"name":"RoBERTa","r":[0.31,0.94,0.69,0.991,0.97],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"magenta"},"name":"CTM","r":[0.99,0.97,0.96,0.92,0.97],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222222 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d90f27da-1f07-44a6-b1f4-172a42b9cf3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d90f27da-1f07-44a6-b1f4-172a42b9cf3f")) {                    Plotly.newPlot(                        "d90f27da-1f07-44a6-b1f4-172a42b9cf3f",                        [{"fill":"none","line":{"color":"limegreen"},"name":"LDA","r":[-0.19,-0.19,-0.01,-0.03,-0.21],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orange"},"name":"Top2Vec","r":[-0.06,-0.01,-0.1,-0.22,-0.02],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"royalblue"},"name":"NMF","r":[0.12,0.21,0.09,-0.07,0.03],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orangered"},"name":"BERTopic","r":[-0.01,-0.04,-0.029,-0.17,-0.03],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"cyan"},"name":"RoBERTa","r":[-0.01,-0.05,-0.061,-0.15,-0.01],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"magenta"},"name":"CTM","r":[-0.3,-0.08,-0.03,-0.21,-0.11],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#4 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="24a3ec7e-2323-4c2d-9ee3-9bcaa48adbfd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24a3ec7e-2323-4c2d-9ee3-9bcaa48adbfd")) {                    Plotly.newPlot(                        "24a3ec7e-2323-4c2d-9ee3-9bcaa48adbfd",                        [{"fill":"none","line":{"color":"limegreen"},"name":"LDA","r":[-6.56,-6.68,-0.11,-1.06,-6.23],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orange"},"name":"Top2Vec","r":[-3.42,-3.42,-4.57,-6.72,-2.72],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"royalblue"},"name":"NMF","r":[0.01,0.59,-0.05,-3.1,-1.05],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orangered"},"name":"BERTopic","r":[-0.1,-2.66,-1.53,-6.59,-2.8],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"cyan"},"name":"RoBERTa","r":[-0.14,-2.69,-1.32,-5.91,-1.64],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"magenta"},"name":"CTM","r":[-8.93,-4.61,-2.34,-6.57,-3.53],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b448cef9-cd87-4101-8155-3218491f3cf3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b448cef9-cd87-4101-8155-3218491f3cf3")) {                    Plotly.newPlot(                        "b448cef9-cd87-4101-8155-3218491f3cf3",                        [{"fill":"none","line":{"color":"limegreen"},"name":"LDA","r":[-8.45,-8.68,-1.65,-3.62,-5.92],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orange"},"name":"Top2Vec","r":[-1.52,-1.17,-5.38,-8.1,-2.74],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"royalblue"},"name":"NMF","r":[-2.09,-1.7,-3.03,-6.27,-3.46],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orangered"},"name":"BERTopic","r":[-0.63,-2.02,-4.72,-12.35,-5.06],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"cyan"},"name":"RoBERTa","r":[-0.83,-1.86,-4.72,-11.91,-3.43],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"magenta"},"name":"CTM","r":[-5.51,-4.44,-4.94,-10.7,-2.67],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cbb5b7f3-f412-42a4-b531-fca753353b07" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cbb5b7f3-f412-42a4-b531-fca753353b07")) {                    Plotly.newPlot(                        "cbb5b7f3-f412-42a4-b531-fca753353b07",                        [{"fill":"none","line":{"color":"limegreen"},"name":"LDA","r":[0.45,0.42,0.37,0.45,0.34],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orange"},"name":"Top2Vec","r":[0.62,0.7,0.56,0.35,0.64],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"royalblue"},"name":"NMF","r":[0.7,0.79,0.59,0.44,0.49],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orangered"},"name":"BERTopic","r":[0.34,0.53,0.31,0.34,0.51],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"cyan"},"name":"RoBERTa","r":[0.34,0.54,0.31,0.36,0.52],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"magenta"},"name":"CTM","r":[0.37,0.61,0.58,0.51,0.42],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222, ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f77251a3-29d0-49a8-814d-e5cf85eaa551" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f77251a3-29d0-49a8-814d-e5cf85eaa551")) {                    Plotly.newPlot(                        "f77251a3-29d0-49a8-814d-e5cf85eaa551",                        [{"fill":"none","line":{"color":"black"},"name":"LDA","r":[0.87,0.94,0.21,0.38,0.6],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"dimgray"},"name":"Top2Vec","r":[0.92,0.94,0.84,0.61,0.91],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"darkgrey"},"name":"NMF","r":[0.83,0.82,0.82,0.65,0.58],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"gainsboro"},"name":"BERTopic","r":[0.47,0.61,0.45,0.71,0.78],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"white"},"name":"RoBERTa","r":[0.25,0.57,0.59,0.67,0.75],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"silver"},"name":"CTM","r":[0.88,0.78,0.61,0.61,0.48],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="24c3a6da-a47e-4ad7-a554-f80160a52679" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24c3a6da-a47e-4ad7-a554-f80160a52679")) {                    Plotly.newPlot(                        "24c3a6da-a47e-4ad7-a554-f80160a52679",                        [{"fill":"none","line":{"color":"black"},"name":"LDA","r":[0.98,0.99,0.56,0.7,0.87],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"dimgray"},"name":"Top2Vec","r":[0.98,0.98,0.995,0.97,0.998],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"darkgrey"},"name":"NMF","r":[0.98,0.98,0.986,0.947,0.99],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"gainsboro"},"name":"BERTopic","r":[0.21,0.96,0.925,0.996,0.99],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"white"},"name":"RoBERTa","r":[0.31,0.94,0.69,0.991,0.97],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"silver"},"name":"CTM","r":[0.99,0.97,0.96,0.92,0.97],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="43d81463-abe5-45ff-94bd-a71f183fac2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43d81463-abe5-45ff-94bd-a71f183fac2d")) {                    Plotly.newPlot(                        "43d81463-abe5-45ff-94bd-a71f183fac2d",                        [{"fill":"none","line":{"color":"black"},"name":"LDA","r":[-0.19,-0.19,-0.01,-0.03,-0.21],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"dimgray"},"name":"Top2Vec","r":[-0.06,-0.01,-0.1,-0.22,-0.02],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"darkgrey"},"name":"NMF","r":[0.12,0.21,0.09,-0.07,0.03],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"gainsboro"},"name":"BERTopic","r":[-0.01,-0.04,-0.029,-0.17,-0.03],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"white"},"name":"RoBERTa","r":[-0.01,-0.05,-0.061,-0.15,-0.01],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"silver"},"name":"CTM","r":[-0.3,-0.08,-0.03,-0.21,-0.11],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="39bad0c6-65e0-4eba-a7c3-25889f0fb1b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("39bad0c6-65e0-4eba-a7c3-25889f0fb1b8")) {                    Plotly.newPlot(                        "39bad0c6-65e0-4eba-a7c3-25889f0fb1b8",                        [{"fill":"none","line":{"color":"black"},"name":"LDA","r":[-6.56,-6.68,-0.11,-1.06,-6.23],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"dimgray"},"name":"Top2Vec","r":[-3.42,-3.42,-4.57,-6.72,-2.72],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"darkgrey"},"name":"NMF","r":[0.01,0.59,-0.05,-3.1,-1.05],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"gainsboro"},"name":"BERTopic","r":[-0.1,-2.66,-1.53,-6.59,-2.8],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"white"},"name":"RoBERTa","r":[-0.14,-2.69,-1.32,-5.91,-1.64],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"silver"},"name":"CTM","r":[-8.93,-4.61,-2.34,-6.57,-3.53],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="30ed2d66-0a1f-4fdd-af9e-41b5f8245ffc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30ed2d66-0a1f-4fdd-af9e-41b5f8245ffc")) {                    Plotly.newPlot(                        "30ed2d66-0a1f-4fdd-af9e-41b5f8245ffc",                        [{"fill":"none","line":{"color":"black","dash":"solid"},"name":"LDA","r":[-6.56,-6.68,-0.11,-1.06,-6.23],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"dimgray","dash":"dot"},"name":"Top2Vec","r":[-3.42,-3.42,-4.57,-6.72,-2.72],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"darkgrey","dash":"dash"},"name":"NMF","r":[0.01,0.59,-0.05,-3.1,-1.05],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"gainsboro","dash":"longdash"},"name":"BERTopic","r":[-0.1,-2.66,-1.53,-6.59,-2.8],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"white","dash":"dashdot"},"name":"RoBERTa","r":[-0.14,-2.69,-1.32,-5.91,-1.64],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"silver","dash":"longdashdot"},"name":"CTM","r":[-8.93,-4.61,-2.34,-6.57,-3.53],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3c0a927c-9c6c-4448-bcdd-a96f454bc5fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c0a927c-9c6c-4448-bcdd-a96f454bc5fe")) {                    Plotly.newPlot(                        "3c0a927c-9c6c-4448-bcdd-a96f454bc5fe",                        [{"fill":"none","line":{"color":"black","dash":"solid"},"name":"LDA","r":[-8.45,-8.68,-1.65,-3.62,-5.92],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"dimgray","dash":"dot"},"name":"Top2Vec","r":[-1.52,-1.17,-5.38,-8.1,-2.74],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"darkgrey","dash":"dash"},"name":"NMF","r":[-2.09,-1.7,-3.03,-6.27,-3.46],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"gainsboro","dash":"longdash"},"name":"BERTopic","r":[-0.63,-2.02,-4.72,-12.35,-5.06],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"white","dash":"dashdot"},"name":"RoBERTa","r":[-0.83,-1.86,-4.72,-11.91,-3.43],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"silver","dash":"longdashdot"},"name":"CTM","r":[-5.51,-4.44,-4.94,-10.7,-2.67],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="45ae7235-048c-4c42-a907-e9c23a5f8f64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45ae7235-048c-4c42-a907-e9c23a5f8f64")) {                    Plotly.newPlot(                        "45ae7235-048c-4c42-a907-e9c23a5f8f64",                        [{"fill":"none","line":{"color":"black","dash":"solid"},"name":"LDA","r":[0.45,0.42,0.37,0.45,0.34],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"dimgray","dash":"dot"},"name":"Top2Vec","r":[0.62,0.7,0.56,0.35,0.64],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"darkgrey","dash":"dash"},"name":"NMF","r":[0.7,0.79,0.59,0.44,0.49],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"gainsboro","dash":"longdash"},"name":"BERTopic","r":[0.34,0.53,0.31,0.34,0.51],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"white","dash":"dashdot"},"name":"RoBERTa","r":[0.34,0.54,0.31,0.36,0.52],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"},{"fill":"none","line":{"color":"silver","dash":"longdashdot"},"name":"CTM","r":[0.37,0.61,0.58,0.51,0.42],"theta":["ATE","TAT","ET","TP","20NG"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0 ...

# %%
# Set use_colors to False to have plots in shades of gray
def radar_chart_dataset(use_colors=None, remove_diversity=True, save_plots=False, use_dash=False):

  if remove_diversity:
    metrics_radar_chart = list(filter(lambda x: x != "irbo" and x != "topic_diversity", metrics))
  else:
    metrics_radar_chart = metrics

  if remove_diversity:
    math_metrics_radar_chart = list(filter(lambda x: x !=  "$irbo$" and x != "$topic diversity$", math_metrics))
  else:
    math_metrics_radar_chart = metrics
  
  for d in datasets:
    min_value = results_df[results_df.dataset==d].min(axis=1).min()
    max_value = results_df[results_df.dataset==d].max(axis=1).max()

    fig = go.Figure()

    for m,c,bw,style in zip(models,colors,colors_bw,dash_styles):
      v = []
      for i in metrics_radar_chart:
        v.append(results[m][d][i])

      if use_colors:
        #mark = go.scatterpolar.Marker.symbol = 107
        line_style = {"color":c}
        fig.add_trace(go.Scatterpolar(
              r=v,
              theta=math_metrics_radar_chart,
              fill='none', #toself to color area
              name=m,
              line = line_style
        ))
      else:
        if use_dash:
          line_style = {"color":bw, "dash":style}
        else:
          line_style = {"color":bw}
        fig.add_trace(go.Scatterpolar(
              r=v,
              theta=math_metrics_radar_chart,
              fill='none', #toself to color area
              name=m,
              line = line_style
        ))
    fig.update_layout(
      #title = "Comparison for {} dataset".format(d),
      width=600,
      polar=dict(
        bgcolor='rgb(255,255,255)', #background color of the chart
        radialaxis=dict(
          visible=True,
          gridcolor="#999",
          range=[min_value, max_value]
        )),
      showlegend=True,
      legend=dict(
          orientation="h",
          yanchor="bottom",
          xanchor="center",
          x=0.5,
          y=-0.2
      )
    )

    fig.show(renderer="colab")
    if save_plots:
      if use_colors:
        plot_path = radar_chart_path + "Datasets/radar_chart_colored_"+ d + ".png"
      elif use_dash:
        plot_path = radar_chart_path + "Datasets/radar_chart_dashedLines_"+ d + ".png"
      else:
        plot_path = radar_chart_path + "Datasets/radar_chart_"+ d + ".png"
      fig.write_image(plot_path)

radar_chart_dataset(use_colors=colors, save_plots=True, use_dash=False)
radar_chart_dataset(use_colors=None, save_plots=True, use_dash=False)
radar_chart_dataset(use_colors=None, save_plots=True, use_dash=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fff8bb08-7d0a-48aa-a9cf-8d48f0252947" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fff8bb08-7d0a-48aa-a9cf-8d48f0252947")) {                    Plotly.newPlot(                        "fff8bb08-7d0a-48aa-a9cf-8d48f0252947",                        [{"fill":"none","line":{"color":"limegreen"},"name":"LDA","r":[-0.19,-6.56,-8.45,0.45],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orange"},"name":"Top2Vec","r":[-0.06,-3.42,-1.52,0.62],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"royalblue"},"name":"NMF","r":[0.12,0.01,-2.09,0.7],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orangered"},"name":"BERTopic","r":[-0.01,-0.1,-0.63,0.34],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"cyan"},"name":"RoBERTa","r":[-0.01,-0.14,-0.83,0.34],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"magenta"},"name":"CTM","r":[-0.3,-8.93,-5.51,0.37],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"out ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d805a842-10ff-46cd-8ed7-7692e85728de" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d805a842-10ff-46cd-8ed7-7692e85728de")) {                    Plotly.newPlot(                        "d805a842-10ff-46cd-8ed7-7692e85728de",                        [{"fill":"none","line":{"color":"limegreen"},"name":"LDA","r":[-0.19,-6.68,-8.68,0.42],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orange"},"name":"Top2Vec","r":[-0.01,-3.42,-1.17,0.7],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"royalblue"},"name":"NMF","r":[0.21,0.59,-1.7,0.79],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orangered"},"name":"BERTopic","r":[-0.04,-2.66,-2.02,0.53],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"cyan"},"name":"RoBERTa","r":[-0.05,-2.69,-1.86,0.54],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"magenta"},"name":"CTM","r":[-0.08,-4.61,-4.44,0.61],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"ou ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a7e57869-546b-4fc8-99dc-70cf5d7347a3" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7e57869-546b-4fc8-99dc-70cf5d7347a3")) {                    Plotly.newPlot(                        "a7e57869-546b-4fc8-99dc-70cf5d7347a3",                        [{"fill":"none","line":{"color":"limegreen"},"name":"LDA","r":[-0.01,-0.11,-1.65,0.37],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orange"},"name":"Top2Vec","r":[-0.1,-4.57,-5.38,0.56],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"royalblue"},"name":"NMF","r":[0.09,-0.05,-3.03,0.59],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orangered"},"name":"BERTopic","r":[-0.029,-1.53,-4.72,0.31],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"cyan"},"name":"RoBERTa","r":[-0.061,-1.32,-4.72,0.31],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"magenta"},"name":"CTM","r":[-0.03,-2.34,-4.94,0.58],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="66675a39-0816-4834-b08c-2f17799c00eb" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66675a39-0816-4834-b08c-2f17799c00eb")) {                    Plotly.newPlot(                        "66675a39-0816-4834-b08c-2f17799c00eb",                        [{"fill":"none","line":{"color":"limegreen"},"name":"LDA","r":[-0.03,-1.06,-3.62,0.45],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orange"},"name":"Top2Vec","r":[-0.22,-6.72,-8.1,0.35],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"royalblue"},"name":"NMF","r":[-0.07,-3.1,-6.27,0.44],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orangered"},"name":"BERTopic","r":[-0.17,-6.59,-12.35,0.34],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"cyan"},"name":"RoBERTa","r":[-0.15,-5.91,-11.91,0.36],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"magenta"},"name":"CTM","r":[-0.21,-6.57,-10.7,0.51],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fa2706c0-fb1c-4474-a85d-8a8db89daf02" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa2706c0-fb1c-4474-a85d-8a8db89daf02")) {                    Plotly.newPlot(                        "fa2706c0-fb1c-4474-a85d-8a8db89daf02",                        [{"fill":"none","line":{"color":"limegreen"},"name":"LDA","r":[-0.21,-6.23,-5.92,0.34],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orange"},"name":"Top2Vec","r":[-0.02,-2.72,-2.74,0.64],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"royalblue"},"name":"NMF","r":[0.03,-1.05,-3.46,0.49],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"orangered"},"name":"BERTopic","r":[-0.03,-2.8,-5.06,0.51],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"cyan"},"name":"RoBERTa","r":[-0.01,-1.64,-3.43,0.52],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"magenta"},"name":"CTM","r":[-0.11,-3.53,-2.67,0.42],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7666a68e-6068-45fd-85a6-870b5c7d47c5" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7666a68e-6068-45fd-85a6-870b5c7d47c5")) {                    Plotly.newPlot(                        "7666a68e-6068-45fd-85a6-870b5c7d47c5",                        [{"fill":"none","line":{"color":"black"},"name":"LDA","r":[-0.19,-6.56,-8.45,0.45],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"dimgray"},"name":"Top2Vec","r":[-0.06,-3.42,-1.52,0.62],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"darkgrey"},"name":"NMF","r":[0.12,0.01,-2.09,0.7],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"gainsboro"},"name":"BERTopic","r":[-0.01,-0.1,-0.63,0.34],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"white"},"name":"RoBERTa","r":[-0.01,-0.14,-0.83,0.34],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"silver"},"name":"CTM","r":[-0.3,-8.93,-5.51,0.37],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outline ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="16742767-464f-4267-bdb7-210e9add8bfb" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16742767-464f-4267-bdb7-210e9add8bfb")) {                    Plotly.newPlot(                        "16742767-464f-4267-bdb7-210e9add8bfb",                        [{"fill":"none","line":{"color":"black"},"name":"LDA","r":[-0.19,-6.68,-8.68,0.42],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"dimgray"},"name":"Top2Vec","r":[-0.01,-3.42,-1.17,0.7],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"darkgrey"},"name":"NMF","r":[0.21,0.59,-1.7,0.79],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"gainsboro"},"name":"BERTopic","r":[-0.04,-2.66,-2.02,0.53],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"white"},"name":"RoBERTa","r":[-0.05,-2.69,-1.86,0.54],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"silver"},"name":"CTM","r":[-0.08,-4.61,-4.44,0.61],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlin ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6ffae69f-5e17-4de1-a5a0-66e6b44fffae" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ffae69f-5e17-4de1-a5a0-66e6b44fffae")) {                    Plotly.newPlot(                        "6ffae69f-5e17-4de1-a5a0-66e6b44fffae",                        [{"fill":"none","line":{"color":"black"},"name":"LDA","r":[-0.01,-0.11,-1.65,0.37],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"dimgray"},"name":"Top2Vec","r":[-0.1,-4.57,-5.38,0.56],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"darkgrey"},"name":"NMF","r":[0.09,-0.05,-3.03,0.59],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"gainsboro"},"name":"BERTopic","r":[-0.029,-1.53,-4.72,0.31],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"white"},"name":"RoBERTa","r":[-0.061,-1.32,-4.72,0.31],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"silver"},"name":"CTM","r":[-0.03,-2.34,-4.94,0.58],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"ou ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2a1501b2-cb64-4cc1-9a8d-718100325832" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a1501b2-cb64-4cc1-9a8d-718100325832")) {                    Plotly.newPlot(                        "2a1501b2-cb64-4cc1-9a8d-718100325832",                        [{"fill":"none","line":{"color":"black"},"name":"LDA","r":[-0.03,-1.06,-3.62,0.45],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"dimgray"},"name":"Top2Vec","r":[-0.22,-6.72,-8.1,0.35],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"darkgrey"},"name":"NMF","r":[-0.07,-3.1,-6.27,0.44],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"gainsboro"},"name":"BERTopic","r":[-0.17,-6.59,-12.35,0.34],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"white"},"name":"RoBERTa","r":[-0.15,-5.91,-11.91,0.36],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"silver"},"name":"CTM","r":[-0.21,-6.57,-10.7,0.51],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"ou ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="45c805ff-8558-4a61-839c-bb93a26e6409" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45c805ff-8558-4a61-839c-bb93a26e6409")) {                    Plotly.newPlot(                        "45c805ff-8558-4a61-839c-bb93a26e6409",                        [{"fill":"none","line":{"color":"black"},"name":"LDA","r":[-0.21,-6.23,-5.92,0.34],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"dimgray"},"name":"Top2Vec","r":[-0.02,-2.72,-2.74,0.64],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"darkgrey"},"name":"NMF","r":[0.03,-1.05,-3.46,0.49],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"gainsboro"},"name":"BERTopic","r":[-0.03,-2.8,-5.06,0.51],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"white"},"name":"RoBERTa","r":[-0.01,-1.64,-3.43,0.52],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"silver"},"name":"CTM","r":[-0.11,-3.53,-2.67,0.42],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outl ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="eae6a486-0373-4a0b-af8b-b784f9304603" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eae6a486-0373-4a0b-af8b-b784f9304603")) {                    Plotly.newPlot(                        "eae6a486-0373-4a0b-af8b-b784f9304603",                        [{"fill":"none","line":{"color":"black","dash":"solid"},"name":"LDA","r":[-0.01,-0.11,-1.65,0.37],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"dimgray","dash":"dot"},"name":"Top2Vec","r":[-0.1,-4.57,-5.38,0.56],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"darkgrey","dash":"dash"},"name":"NMF","r":[0.09,-0.05,-3.03,0.59],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"gainsboro","dash":"longdash"},"name":"BERTopic","r":[-0.029,-1.53,-4.72,0.31],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"white","dash":"dashdot"},"name":"RoBERTa","r":[-0.061,-1.32,-4.72,0.31],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"silver","dash":"longdashdot"},"name":"CTM","r":[-0.03,-2.34,-4.94,0.58],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="886add9d-bd74-4074-b2ff-09835d6f7a0b" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("886add9d-bd74-4074-b2ff-09835d6f7a0b")) {                    Plotly.newPlot(                        "886add9d-bd74-4074-b2ff-09835d6f7a0b",                        [{"fill":"none","line":{"color":"black","dash":"solid"},"name":"LDA","r":[-0.03,-1.06,-3.62,0.45],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"dimgray","dash":"dot"},"name":"Top2Vec","r":[-0.22,-6.72,-8.1,0.35],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"darkgrey","dash":"dash"},"name":"NMF","r":[-0.07,-3.1,-6.27,0.44],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"gainsboro","dash":"longdash"},"name":"BERTopic","r":[-0.17,-6.59,-12.35,0.34],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"white","dash":"dashdot"},"name":"RoBERTa","r":[-0.15,-5.91,-11.91,0.36],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"silver","dash":"longdashdot"},"name":"CTM","r":[-0.21,-6.57,-10.7,0.51],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d4d9fc3a-615a-4963-8686-dbfce40bd183" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4d9fc3a-615a-4963-8686-dbfce40bd183")) {                    Plotly.newPlot(                        "d4d9fc3a-615a-4963-8686-dbfce40bd183",                        [{"fill":"none","line":{"color":"black","dash":"solid"},"name":"LDA","r":[-0.21,-6.23,-5.92,0.34],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"dimgray","dash":"dot"},"name":"Top2Vec","r":[-0.02,-2.72,-2.74,0.64],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"darkgrey","dash":"dash"},"name":"NMF","r":[0.03,-1.05,-3.46,0.49],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"gainsboro","dash":"longdash"},"name":"BERTopic","r":[-0.03,-2.8,-5.06,0.51],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"white","dash":"dashdot"},"name":"RoBERTa","r":[-0.01,-1.64,-3.43,0.52],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"},{"fill":"none","line":{"color":"silver","dash":"longdashdot"},"name":"CTM","r":[-0.11,-3.53,-2.67,0.42],"theta":["$c_{npmi}$","$c_{uci}$","$c_{umass}$","$c_{v}$"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888 ...

# %% [markdown]
# ### Bar Charts

# %%
used_colors = colors #colors_bw
sns.set(style='white', rc={'figure.figsize':(12,8)}, font_scale=1.6)
# m = "c_uci"
for i,m in enumerate(metrics):
  plt.figure()
  plt.margins(x=0.1)
  if m not in ["topic_diversity", "irbo"]: #coherence
    s = sns.barplot(y="dataset", x=m, hue="model", data=results_df, orient="h", palette = used_colors, edgecolor=".5")
    plt.ylabel("Datasets")#, fontdict={"fontsize":15})
    plt.xlabel("Coherence value ({})".format(math_metrics[i]))#, fontdict={"fontsize":15})
  else: # diversity
    s = sns.barplot(y=m, x="dataset", hue="model", data=results_df, orient="v", palette = used_colors, edgecolor=".5")
    if m == "irbo":
      plt.ylabel("Topic diversity ({})".format(math_metrics[i]))#, fontdict={"fontsize":15})
    else:
      plt.ylabel("$\\textit{Topic diversity}$")#, fontdict={"fontsize":15})
    plt.xlabel("Datasets")#, fontdict={"fontsize":15})
    
  # add bar values
  # for bars_group in s.containers:
  #   s.bar_label(bars_group, padding=3, fontsize=10)

  plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))#, fontsize=15)
  sns.despine()
  plt.tight_layout()
  plt.savefig(bar_charts_path+m+'_seaborn.png')

# %% [markdown]
# ### Line Charts

# %%
sns.set(style='white', rc={'figure.figsize':(12,8)})
m = "c_uci"
for i,m in enumerate(metrics):
  plt.figure()
  s = sns.lineplot(y=m, x="dataset", hue="model", data=results_df)
  plt.ylabel("Coherence value ({})".format(m), fontdict={"fontsize":15})
  plt.xlabel("Datasets", fontdict={"fontsize":15})
  plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=15)
  plt.tight_layout()
  plt.savefig(line_charts_path+m+'_lineplot.png')
